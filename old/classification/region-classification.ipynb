# %%
import cv2
import math
import pandas as pd
import torch
import re

from tqdm.notebook import tqdm
from pathlib import Path
from transformers import (
    ViTForImageClassification, 
    ViTImageProcessor)
from typing import Tuple

# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\12ped\anaconda3\envs\mestrado-segmentation\lib\site-packages (3.1.9)

# %%
# === Codigo usado para copiar as imagens do dataset com oclusao todas para uma unica pasta

from pathlib import Path

regex = r"\w+(?= )"

dst_dir = Path(r"C:\Users\12ped\Desktop\UNIFESP2_completo")
dst_dir.mkdir(parents=True, exist_ok=True)

dataset_path = Path(r"C:\Users\12ped\Desktop\COM APARATO - 10 RN")

for f_path in dataset_path.rglob('*'):
   if f_path.is_file() and f_path.suffix in ['.jpg', '.jpeg', '.png']:
       infant_id = re.match(regex, f_path.parent.name)[0]
       dst_path = dst_dir / f'{infant_id}_{f_path.name}'
       dst_path.write_bytes(f_path.read_bytes()) # Copy file

# %%
# = Data (Images + Face masks)
#FULL_IMAGES_PATH = Path(r'D:\ComputerScience\Mestrado\data\datasets\Occlusion\images')
#FULL_IMAGES_PATH = Path(r'D:\ComputerScience\Mestrado\data\UNIFESP\all')
#CROPS_PATH = Path(r'D:\ComputerScience\Mestrado\lncc\data\Results\Exp1-Mosaic\UNIFESP 360\Dataset\Regioes\com_dor')

# FULL_IMAGES_PATH = Path(r'D:\ComputerScience\Mestrado\lncc\data\Datasets\UNIFESP2_completo\com_dor')
# CROPS_PATH = Path(r'D:\ComputerScience\Mestrado\lncc\data\Results\Exp1-Mosaic\UNIFESP2_completo\Dataset\Regioes\sem_dor')

FULL_IMAGES_PATH = Path(r'C:\Users\12ped\Desktop\UNIFESP2_completo')
CROPS_PATH = Path(r'D:\ComputerScience\Mestrado\lncc\data\Results\Exp1-Mosaic\UNIFESP2_completo\Dataset\Regioes\sem_dor')

# = Trained models
VIT_PATH = Path(r'D:\ComputerScience\Mestrado\results\classification_models\ViT')

# = Mapping variables
ID2LABEL = {0: 'presente', 1: 'ausente'}
ACRONYM2REGION = {
    'BA':'Boca',
    'BE':'Boca',
    'FP':'Fenda palpebral',
    'FS':'Fronte',
    'SN':'Sulco nasolabial',
}
REGION2ACRONYM = {
    region: acronym for acronym, region in ACRONYM2REGION
}

# = Aux constants
BATCH_SIZE = 10

# = Excel writer
writer = pd.ExcelWriter("results.xlsx", engine="xlsxwriter")

# %%
def load_vit(training_set_name:str, region:str) -> Tuple[ViTForImageClassification,ViTImageProcessor]:
    model_path = VIT_PATH / training_set_name / region
    model = ViTForImageClassification.from_pretrained(model_path)
    processor = ViTImageProcessor.from_pretrained(model_path)
    model.to('cuda')
    return model, processor

# %%
def process_images_vit(image_paths, model, processor):
    images = [cv2.cvtColor(cv2.imread(str(img_path)), cv2.COLOR_BGR2RGB) for img_path in image_paths]
    inputs = processor(images=images, return_tensors="pt") # pt = torch.tensor
    inputs.to('cuda')
    logits = model(**inputs).logits
    return [model.config.id2label[lgt.argmax(-1).item()] for lgt in logits]

# %%
def highlight(col):
    """Process a pandas dataframe to set background color to red or green depending on the cell value. Use with dataframe.style.apply."""
    return ['background-color: red;' if value == 0 else 'background-color: green;' for value in col.values]

def batch(iterable, n=1):
    """Create a batched list"""
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

# %% [markdown]
# ---
#
# ## CLASSIFICAR COM IMAGEM COMPLETA

# %%
DATASET = 'UNIFESP360RegiaoImagem'

# = Image paths
#img_files = sorted(list(FULL_IMAGES_PATH.glob('*')), key=lambda a: int(a.stem[1:]))
img_files = sorted(list(FULL_IMAGES_PATH.glob('*')))

cols = {region: [] for region in ACRONYM2REGION.keys()}
index = [f.stem for f in img_files]
for region in tqdm(ACRONYM2REGION.keys()):
    vit_model, vit_processor = load_vit(DATASET, region)
    for files_batch in tqdm(batch(img_files, n=BATCH_SIZE), total=math.ceil(len(img_files)/BATCH_SIZE)):
        vit_predictions = process_images_vit(files_batch, vit_model, vit_processor)
        cols[region].extend(vit_predictions)
        del files_batch

df = pd.DataFrame(cols, index=index)
df_image = df.style.apply(highlight, axis=0)
display(df_image)

df_image.to_excel(writer, sheet_name=DATASET)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# <style type="text/css">
# #T_efbd5_row0_col0, #T_efbd5_row1_col0, #T_efbd5_row1_col3, #T_efbd5_row2_col0, #T_efbd5_row2_col3, #T_efbd5_row3_col0, #T_efbd5_row4_col0, #T_efbd5_row5_col0, #T_efbd5_row5_col1, #T_efbd5_row10_col0, #T_efbd5_row12_col0, #T_efbd5_row15_col0, #T_efbd5_row16_col4, #T_efbd5_row18_col4, #T_efbd5_row19_col0, #T_efbd5_row19_col3, #T_efbd5_row20_col0, #T_efbd5_row20_col3, #T_efbd5_row28_col3, #T_efbd5_row31_col0, #T_efbd5_row31_col1, #T_efbd5_row31_col3, #T_efbd5_row31_col4, #T_efbd5_row32_col0, #T_efbd5_row32_col1, #T_efbd5_row32_col3, #T_efbd5_row32_col4, #T_efbd5_row33_col0, #T_efbd5_row33_col1, #T_efbd5_row33_col3, #T_efbd5_row33_col4, #T_efbd5_row34_col1, #T_efbd5_row34_col3, #T_efbd5_row34_col4, #T_efbd5_row35_col1, #T_efbd5_row35_col4, #T_efbd5_row36_col0, #T_efbd5_row36_col1, #T_efbd5_row36_col3, #T_efbd5_row36_col4, #T_efbd5_row37_col0, #T_efbd5_row37_col1, #T_efbd5_row37_col3, #T_efbd5_row37_col4, #T_efbd5_row38_col1, #T_efbd5_row38_col4, #T_efbd5_row39_col0, #T_efbd5_row39_col1, #T_efbd5_row39_col2, #T_efbd5_row39_col4, #T_efbd5_row40_col0, #T_efbd5_row41_col0, #T_efbd5_row43_col0, #T_efbd5_row44_col0, #T_efbd5_row44_col1, #T_efbd5_row45_col0, #T_efbd5_row46_col0, #T_efbd5_row46_col1, #T_efbd5_row47_col0, #T_efbd5_row48_col0, #T_efbd5_row48_col1, #T_efbd5_row48_col4, #T_efbd5_row49_col0, #T_efbd5_row49_col1, #T_efbd5_row49_col3, #T_efbd5_row49_col4, #T_efbd5_row50_col0, #T_efbd5_row50_col1, #T_efbd5_row50_col3, #T_efbd5_row50_col4, #T_efbd5_row51_col0, #T_efbd5_row51_col1, #T_efbd5_row51_col3, #T_efbd5_row51_col4, #T_efbd5_row52_col0, #T_efbd5_row52_col1, #T_efbd5_row52_col2, #T_efbd5_row52_col3, #T_efbd5_row53_col0, #T_efbd5_row53_col1, #T_efbd5_row53_col3, #T_efbd5_row53_col4, #T_efbd5_row54_col0, #T_efbd5_row54_col1, #T_efbd5_row54_col4, #T_efbd5_row55_col0, #T_efbd5_row55_col1, #T_efbd5_row56_col0, #T_efbd5_row56_col1, #T_efbd5_row56_col4, #T_efbd5_row57_col0, #T_efbd5_row57_col1, #T_efbd5_row57_col2, #T_efbd5_row57_col4, #T_efbd5_row58_col0, #T_efbd5_row58_col1, #T_efbd5_row58_col3, #T_efbd5_row58_col4, #T_efbd5_row59_col0, #T_efbd5_row59_col1, #T_efbd5_row59_col2, #T_efbd5_row59_col3, #T_efbd5_row59_col4, #T_efbd5_row60_col0, #T_efbd5_row60_col1, #T_efbd5_row60_col2, #T_efbd5_row60_col3, #T_efbd5_row60_col4, #T_efbd5_row61_col0, #T_efbd5_row61_col1, #T_efbd5_row61_col2, #T_efbd5_row61_col3, #T_efbd5_row61_col4, #T_efbd5_row62_col0, #T_efbd5_row62_col1, #T_efbd5_row62_col2, #T_efbd5_row62_col3, #T_efbd5_row62_col4, #T_efbd5_row63_col0, #T_efbd5_row63_col1, #T_efbd5_row63_col3, #T_efbd5_row63_col4, #T_efbd5_row64_col0, #T_efbd5_row64_col1, #T_efbd5_row64_col3, #T_efbd5_row64_col4, #T_efbd5_row65_col0, #T_efbd5_row65_col1, #T_efbd5_row65_col3, #T_efbd5_row66_col0, #T_efbd5_row66_col1, #T_efbd5_row66_col3, #T_efbd5_row66_col4, #T_efbd5_row67_col0, #T_efbd5_row67_col1, #T_efbd5_row67_col2, #T_efbd5_row67_col3, #T_efbd5_row67_col4, #T_efbd5_row68_col0, #T_efbd5_row68_col1, #T_efbd5_row68_col2, #T_efbd5_row68_col3, #T_efbd5_row68_col4, #T_efbd5_row69_col0, #T_efbd5_row69_col1, #T_efbd5_row69_col2, #T_efbd5_row69_col3, #T_efbd5_row69_col4, #T_efbd5_row70_col0, #T_efbd5_row70_col1, #T_efbd5_row70_col3, #T_efbd5_row70_col4, #T_efbd5_row71_col0, #T_efbd5_row71_col1, #T_efbd5_row71_col2, #T_efbd5_row71_col3, #T_efbd5_row71_col4, #T_efbd5_row72_col0, #T_efbd5_row72_col1, #T_efbd5_row72_col3, #T_efbd5_row73_col0, #T_efbd5_row73_col1, #T_efbd5_row73_col3, #T_efbd5_row74_col0, #T_efbd5_row74_col1, #T_efbd5_row74_col3, #T_efbd5_row75_col0, #T_efbd5_row75_col1, #T_efbd5_row75_col3, #T_efbd5_row76_col0, #T_efbd5_row76_col1, #T_efbd5_row76_col3, #T_efbd5_row77_col0, #T_efbd5_row77_col1, #T_efbd5_row78_col0, #T_efbd5_row78_col1, #T_efbd5_row78_col3, #T_efbd5_row79_col0, #T_efbd5_row79_col1, #T_efbd5_row80_col0, #T_efbd5_row80_col1, #T_efbd5_row80_col3, #T_efbd5_row81_col0, #T_efbd5_row81_col1, #T_efbd5_row81_col3, #T_efbd5_row82_col0, #T_efbd5_row82_col1, #T_efbd5_row82_col3, #T_efbd5_row83_col0, #T_efbd5_row83_col1, #T_efbd5_row83_col3 ...

# %% [markdown]
# ---
#
# # Classificar com recorte das partes da face

# %%
DATASET = 'UNIFESP360RegiaoRecorte'

cols = {region: [] for region in ACRONYM2REGION.keys()}
files = [[f for f in list((CROPS_PATH/region).glob('*'))] for region in ACRONYM2REGION.values()] # Get all file names
files_set = list(map(lambda paths: set(f.stem for f in paths), files))
index = sorted(set.intersection(*files_set)) # Get the intersection of file names (so we only process the files that have all regions, just in case)
if len(diff := (set.difference(set.union(*files_set), index))): # union - intersection
    print('Some regions are missing, please check if these files exists in all folders:', ','.join(list(diff)))
else:
    for region in tqdm(ACRONYM2REGION.keys()):
        img_files = sorted(list((CROPS_PATH/ACRONYM2REGION[region]).glob('*')))
        vit_model, vit_processor = load_vit(DATASET, region)
        for files_batch in tqdm(batch(img_files, n=BATCH_SIZE), total=math.ceil(len(img_files)/BATCH_SIZE)):
            try:
                vit_predictions = process_images_vit(files_batch, vit_model, vit_processor)
            except Exception as e:
                print(e)
            cols[region].extend(vit_predictions)

    df = pd.DataFrame(cols, index=index)
    df_crop = df.style.apply(highlight, axis=0)
    display(df_crop)

    df_crop.to_excel(writer, sheet_name=DATASET)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
# <style type="text/css">
# #T_afc39_row0_col0, #T_afc39_row0_col4, #T_afc39_row1_col0, #T_afc39_row1_col4, #T_afc39_row2_col0, #T_afc39_row2_col1, #T_afc39_row3_col0, #T_afc39_row4_col0, #T_afc39_row5_col0, #T_afc39_row5_col4, #T_afc39_row6_col0, #T_afc39_row6_col4, #T_afc39_row7_col4, #T_afc39_row9_col0, #T_afc39_row11_col0, #T_afc39_row12_col0, #T_afc39_row13_col0, #T_afc39_row13_col4, #T_afc39_row14_col0, #T_afc39_row15_col0, #T_afc39_row16_col2, #T_afc39_row16_col3, #T_afc39_row16_col4, #T_afc39_row17_col1, #T_afc39_row17_col3, #T_afc39_row17_col4, #T_afc39_row18_col1, #T_afc39_row18_col3, #T_afc39_row19_col0, #T_afc39_row19_col1, #T_afc39_row19_col2, #T_afc39_row19_col3, #T_afc39_row19_col4, #T_afc39_row20_col1, #T_afc39_row20_col2, #T_afc39_row20_col3, #T_afc39_row21_col2, #T_afc39_row21_col3, #T_afc39_row21_col4, #T_afc39_row22_col3, #T_afc39_row22_col4, #T_afc39_row23_col1, #T_afc39_row23_col3, #T_afc39_row23_col4, #T_afc39_row24_col1, #T_afc39_row24_col3, #T_afc39_row25_col1, #T_afc39_row25_col2, #T_afc39_row25_col3, #T_afc39_row27_col2, #T_afc39_row27_col3, #T_afc39_row27_col4, #T_afc39_row28_col3, #T_afc39_row29_col2, #T_afc39_row29_col3, #T_afc39_row29_col4, #T_afc39_row30_col1, #T_afc39_row30_col2, #T_afc39_row30_col3, #T_afc39_row31_col1, #T_afc39_row31_col2, #T_afc39_row31_col3, #T_afc39_row31_col4, #T_afc39_row32_col0, #T_afc39_row32_col1, #T_afc39_row32_col2, #T_afc39_row32_col3, #T_afc39_row32_col4, #T_afc39_row33_col0, #T_afc39_row33_col1, #T_afc39_row33_col2, #T_afc39_row33_